# %%
import random
students = []
for j in range(50):
    scores = []
    for i in range(5):
        scores.append(random.randint(50,100))
    students.append(scores)

students
# Out:
# [[67, 91, 62, 89, 74],
#  [90, 96, 100, 50, 74],
#  [69, 88, 89, 72, 50],
#  [64, 93, 50, 51, 92],
#  [93, 52, 54, 59, 98],
#  [62, 100, 68, 72, 62],
#  [67, 88, 65, 51, 81],
#  [86, 72, 90, 61, 97],
#  [84, 50, 91, 97, 64],
#  [97, 58, 72, 62, 54],
#  [60, 100, 72, 61, 89],
#  [64, 77, 64, 62, 88],
#  [93, 77, 85, 90, 97],
#  [67, 66, 95, 98, 52],
#  [79, 64, 60, 76, 85],
#  [64, 51, 75, 68, 51],
#  [77, 60, 56, 71, 65],
#  [54, 84, 83, 61, 70],
#  [61, 77, 73, 85, 66],
#  [72, 64, 62, 69, 55],
#  [60, 62, 63, 98, 50],
#  [77, 93, 59, 79, 53],
#  [93, 69, 54, 71, 98],
#  [99, 51, 86, 79, 50],
#  [57, 53, 71, 80, 52],
#  [52, 80, 90, 79, 94],
#  [68, 61, 88, 84, 84],
#  [95, 83, 80, 77, 85],
#  [78, 97, 92, 67, 84],
#  [51, 54, 64, 61, 91],
#  [97, 52, 89, 66, 92],
#  [65, 68, 55, 67, 65],
#  [53, 73, 53, 85, 92],
#  [60, 84, 87, 83, 93],
#  [83, 86, 58, 50, 83],
#  [96, 80, 76, 78, 82],
#  [68, 78, 71, 57, 95],
#  [93, 77, 52, 67, 96],
#  [76, 94, 96, 95, 61],
# ...

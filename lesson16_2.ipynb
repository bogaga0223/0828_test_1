# %%
import numpy as np
import pandas as pd

scores=np.random.randint(50,high=101,size=(50,5))
dataFrame = pd.DataFrame(scores,
             columns=["Chinese","English","Math","Geo","History"],
             index=range(1,51))
dataFrame.index.name= "學號"
dataFrame.columns.name = "科目"
dataFrame
# Out:
# 科目  Chinese  English  Math  Geo  History
# 學號
# 1        51       79    95   91       74
# 2        87       99    94   68       81
# 3        61       71    60   54       63
# 4        91      100    53   93      100
# 5        59       76    89   63       97
# 6        67       86    88   68       85
# 7        57       98    91   55       85
# 8        59       58    62   96       66
# 9        94       65    89   59       98
# 10       57       81    77   87       65
# 11       83       95    81   82       79
# 12       79       64    65   88       93
# 13       94       71    98   79       87
# 14       83       64    84   75       89
# 15       73       83    73   68       78
# 16       56       90    95   86       82
# 17       64      100    81   94       62
# 18       90       55    54   66       53
# 19       99      100    98   97       86
# 20       56       90    62   71       75
# 21       70       72    52   79       79
# 22       57       70    95   65       58
# 23       68       91    64   77       74
# 24       95       69    94   55       86
# 25       84       97    58   72       53
# 26       68       50    84   54       62
# 27       89       99    50   82       83
# 28       61       74    88   63       67
# 29       95       65    51   58       97
# 30       73       83    51   58       50
# 31       81       67    67   71       65
# 32       98       59    79   66       85
# 33       52       57    81   93       97
# 34       88       94    66   96       53
# 35       50       70    62   71       62
# 36       72       84    56   76       55
# 37      100       74    56   54       66
# 38       82       61    68   72       67
# 39       90       67    78   96       83
# 40       79       76    52   91       74
# 41       62       56    56   60       59
# 42       55       52    54   56       84
# 43       69       69    61   77       96
# 44       61       80    74   85       76
# 45       67       63    92   81       95
# 46       93       86    61   52       98
# 47       55       72    87   75       93
# 48       56       54    96   63       70
# 49       66       52    53   50       54
# 50       95       74    56   81       56

# %%
sum_values = dataFrame.sum(axis=1)
avg_values = dataFrame.mean(axis=1)
dataFrame['總分'] = sum_values
dataFrame['平均'] = avg_values
dataFrame
# Out:
# 科目  Chinese  English  Math  Geo  History   總分    平均
# 學號
# 1        51       79    95   91       74  390  78.0
# 2        87       99    94   68       81  429  85.8
# 3        61       71    60   54       63  309  61.8
# 4        91      100    53   93      100  437  87.4
# 5        59       76    89   63       97  384  76.8
# 6        67       86    88   68       85  394  78.8
# 7        57       98    91   55       85  386  77.2
# 8        59       58    62   96       66  341  68.2
# 9        94       65    89   59       98  405  81.0
# 10       57       81    77   87       65  367  73.4
# 11       83       95    81   82       79  420  84.0
# 12       79       64    65   88       93  389  77.8
# 13       94       71    98   79       87  429  85.8
# 14       83       64    84   75       89  395  79.0
# 15       73       83    73   68       78  375  75.0
# 16       56       90    95   86       82  409  81.8
# 17       64      100    81   94       62  401  80.2
# 18       90       55    54   66       53  318  63.6
# 19       99      100    98   97       86  480  96.0
# 20       56       90    62   71       75  354  70.8
# 21       70       72    52   79       79  352  70.4
# 22       57       70    95   65       58  345  69.0
# 23       68       91    64   77       74  374  74.8
# 24       95       69    94   55       86  399  79.8
# 25       84       97    58   72       53  364  72.8
# 26       68       50    84   54       62  318  63.6
# 27       89       99    50   82       83  403  80.6
# 28       61       74    88   63       67  353  70.6
# 29       95       65    51   58       97  366  73.2
# 30       73       83    51   58       50  315  63.0
# 31       81       67    67   71       65  351  70.2
# 32       98       59    79   66       85  387  77.4
# 33       52       57    81   93       97  380  76.0
# 34       88       94    66   96       53  397  79.4
# 35       50       70    62   71       62  315  63.0
# 36       72       84    56   76       55  343  68.6
# 37      100       74    56   54       66  350  70.0
# 38       82       61    68   72       67  350  70.0
# 39       90       67    78   96       83  414  82.8
# 40       79       76    52   91       74  372  74.4
# 41       62       56    56   60       59  293  58.6
# 42       55       52    54   56       84  301  60.2
# 43       69       69    61   77       96  372  74.4
# 44       61       80    74   85       76  376  75.2
# 45       67       63    92   81       95  398  79.6
# 46       93       86    61   52       98  390  78.0
# 47       55       72    87   75       93  382  76.4
# 48       56       54    96   63       70  339  67.8
# 49       66       52    53   50       54  275  55.0
# 50       95       74    56   81       56  362  72.4

# %%
import matplotlib.pyplot as plt

#1 製作figure
fig = plt.figure()

#2 在1上製作一個axes
ax_1 = fig.add_subplot(1,1,1)

#3將圖的數據儲存在axes中
X = [0,1,2]
Y = [3,4,5]
ax_1.plot(X,Y)

#4 顯示圖
plt.show()

# %%
import matplotlib.pyplot as plt

figure =plt.figure()
ax1 = figure.add_subplot(1,3,1)
ax1.set_title("Label1")
ax2 = figure.add_subplot(1,3,2)
ax2.set_title("Label2")
ax3 = figure.add_subplot(1,3,3)
ax3.set_title("Label3")

plt.show()

# %%
figure = plt.figure(figsize=(8,5))
axes = figure.add_subplot(1,1,1)
# x沒寫會預設0,1,2,3,4
axes.plot([-1,-4.3,15,21,31])
#print(axes.get_xticks())
#print(axes.get_xticklabels())
axes.set_xticklabels(['a','b','c','d','e','f','g','h','i','j','k'])
plt.show()
# Out:
# /tmp/ipykernel_2220/577810698.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes.set_xticklabels(['a','b','c','d','e','f','g','h','i','j','k'])
